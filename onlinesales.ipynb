# %% [markdown]
# <a href="https://colab.research.google.com/github/bezerraluis/BootCamp-Data-Science/blob/main/onlinesales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema de Negócios

# %% [markdown]
# #[DataSets](https://www.kaggle.com/datasets/samruddhi4040/online-sales-data/data)

# %% [markdown]
# h1 .Alguns estados tem maior quantidade de vendas
#
# h2  .Algumas cidades tem maoir quantidade de vendas
#
# h3  .Eletronicos vendem mais que roupas
#
# h4  .Sub categoria Phone vende mais que a sub categoria Printers
#
# h5 .Temos mais lucro em vendas com cartão de credito do que com UPI.

# %% [markdown]
# # 1.0 Bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import Image, HTML

# %% [markdown]
# # 2.0 Análise Exploratória

# %%
df_details = pd.read_csv('Details.csv')

# %%
df_details.head(1500)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25681    1096     658         7  Electronics  Electronic Games
# 1     B-26055    5729      64        14    Furniture            Chairs
# 2     B-25955    2927     146         8    Furniture         Bookcases
# 3     B-26093    2847     712         8  Electronics          Printers
# 4     B-25602    2617    1151         4  Electronics            Phones
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-25700       7      -3         2     Clothing       Hankerchief
# 1496  B-25757    3151     -35         7     Clothing          Trousers
# 1497  B-25973    4141    1698        13  Electronics          Printers
# 1498  B-25698       7      -2         1     Clothing       Hankerchief
# 1499  B-25993    4363     305         5    Furniture            Tables
#
#       PaymentMode
# 0             COD
# 1             EMI
# 2             EMI
# 3     Credit Card
# ...

# %%
df_details['Order ID'].value_counts()
# Out:
# B-26056    12
# B-25656    12
# B-25757    11
# B-25999    11
# B-26051    10
#            ..
# B-26065     1
# B-25765     1
# B-25684     1
# B-25739     1
# B-25707     1
# Name: Order ID, Length: 500, dtype: int64

# %%
df_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   int64
#  2   Profit        1500 non-null   int64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
#  6   PaymentMode   1500 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 82.2+ KB

# %%
df_orders = pd.read_csv('Orders.csv')

# %%
df_orders.head()
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      500 non-null    object
#  1   Order Date    500 non-null    object
#  2   CustomerName  500 non-null    object
#  3   State         500 non-null    object
#  4   City          500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %%
df_online = pd.merge(df_orders, df_details, on= 'Order ID')

# %%
df_online.head(100)
# Out:
#    Order ID  Order Date CustomerName          State       City  Amount  \
# 0   B-26055  10-03-2018    Harivansh  Uttar Pradesh    Mathura    5729
# 1   B-26055  10-03-2018    Harivansh  Uttar Pradesh    Mathura     671
# 2   B-26055  10-03-2018    Harivansh  Uttar Pradesh    Mathura     443
# 3   B-26055  10-03-2018    Harivansh  Uttar Pradesh    Mathura      57
# 4   B-26055  10-03-2018    Harivansh  Uttar Pradesh    Mathura     227
# ..      ...         ...          ...            ...        ...     ...
# 95  B-25761  25-08-2018       Madhav  Uttar Pradesh    Mathura     263
# 96  B-25761  25-08-2018       Madhav  Uttar Pradesh    Mathura     328
# 97  B-25761  25-08-2018       Madhav  Uttar Pradesh    Mathura      40
# 98  B-25887  01-12-2018     Vishakha  Uttar Pradesh  Prayagraj    2125
# 99  B-25887  01-12-2018     Vishakha  Uttar Pradesh  Prayagraj      83
#
#     Profit  Quantity     Category      Sub-Category  PaymentMode
# ...

# %%
df_online.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Order Date    1500 non-null   object
#  2   CustomerName  1500 non-null   object
#  3   State         1500 non-null   object
#  4   City          1500 non-null   object
#  5   Amount        1500 non-null   int64
#  6   Profit        1500 non-null   int64
#  7   Quantity      1500 non-null   int64
#  8   Category      1500 non-null   object
#  9   Sub-Category  1500 non-null   object
#  10  PaymentMode   1500 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 140.6+ KB
